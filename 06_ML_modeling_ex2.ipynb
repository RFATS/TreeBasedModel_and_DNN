# %% [markdown]
# # **코스피 지수 예측 실습**
# - 강사가 제작한 코스피 지수 데이터를 예측하는 예측 모델링 실습
# - 데이터 전처리 가능 / 모델 서칭 가능 / 하이퍼 파라메터 서칭 가능
#
# **베이스라인 모델**
# - train_test_split에 아래 파라메터를 적용한 y_test기준
# - test_size=0.3, random_state=42, shuffle=False
# - 평가지표 RMSE를 사용하여 가장 기본적인 회귀 모델로 모델링 한 평가지표가 RMSE 108.1279입니다.
# - 우리의 목표는 RMSE 기준 예측 오차가 가장 작은 모델을 생성하는 것이 목표!!

# %%
# 필요모듈 import
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
# 데이터로딩 및 확인
kospi = pd.read_csv("https://raw.githubusercontent.com/overgroove/ML_lecture_image_data/refs/heads/main/data/kospi.csv", encoding='cp949')
kospi.head()

# %%
# 필요 시 셀 추가하시면서 작업
